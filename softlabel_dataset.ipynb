# %%
import os
os.environ["HF_HOME"] = "/root/autodl-tmp/hf-mirror"
os.environ['HF_ENDPOINT'] = "https://hf-mirror.com"
from datasets import load_from_disk, Dataset
from transformers import AutoTokenizer
# Out:
# /root/miniconda3/envs/prm_openrlhf/lib/python3.10/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
ds = load_from_disk("/root/autodl-tmp/iterative_runs/qwen-math-1.5b-prm/soft_labels/")
# 将 soft_labels 列名称替换为 softlabel
ds = ds.rename_column("soft_labels", "softlabel")
# 保存数据集到 Hugging Face Hub
ds.push_to_hub("weepcat/qwen-math-1.5b-prm-hard-stage1")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/datasets/weepcat/qwen-math-1.5b-prm-hard-stage1/commit/f2baf22c699d8011017f235162305e4b6c280493', commit_message='Upload dataset', commit_description='', oid='f2baf22c699d8011017f235162305e4b6c280493', pr_url=None, repo_url=RepoUrl('https://hf-mirror.com/datasets/weepcat/qwen-math-1.5b-prm-hard-stage1', endpoint='https://hf-mirror.com', repo_type='dataset', repo_id='weepcat/qwen-math-1.5b-prm-hard-stage1'), pr_revision=None, pr_num=None)

# %%
# 找到 ds 中 'value' 中包含 [NEG] 的样本
neg_samples = ds.filter(lambda x: '[NEG]' in x['value'])
# Out:
# Filter:   0%|          | 0/18151 [00:00<?, ? examples/s]

# %%
neg_samples
